# %%
import igraph
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import matplotlib.patches as mpatches
import os
os.chdir("../src")
from build_network_object import build_network_object
from draw_network_by_classification import draw_network_by_classification, compare_degrees_strength
from draw_adjacency_matrix import draw_adjacency_matrix, draw_adjacency_matrix_nolabel
from draw_and_print_communities import draw_and_print_communities, compare_comunity_intersection
from correlations import correlation_industry_pairs, correlation_network_degree,correlation_adjacency_matrix
import seaborn as sns

# %% [markdown]
# # Comparison between Flows and Connection algorithms for 1997-2008 matrices

# %% [markdown]
# ## Flows

# %%
label1 = "Table1_Reduced_matrix_1997_2008_flows"
reduced_matrix_1997_2008 = pd.read_csv("../data/"+label1+".csv", index_col=0)

reduced_matrix_1997_2008_flows = reduced_matrix_1997_2008[reduced_matrix_1997_2008['StartIndst']!=0]

sub_matrix_1997_2008_less1 = reduced_matrix_1997_2008_flows[reduced_matrix_1997_2008_flows['weight']<1].sort_values(by=['weight'], ascending=False)
sub_matrix_1997_2008_flows = sub_matrix_1997_2008_less1[sub_matrix_1997_2008_less1['weight']>0].sort_values(by=['weight'], ascending=False)

print ("Number of links:", sub_matrix_1997_2008_flows.shape[0])
print ("Number of 4-digit industries observed:")
print (len(np.unique([sub_matrix_1997_2008_flows['StartIndst'].values,sub_matrix_1997_2008_flows['FinalIndst'].values])))
sub_matrix_1997_2008_flows[1:50]
# Out:
# Number of links: 2292
# Number of 4-digit industries observed:
# 367
#       StartIndst  FinalIndst    weight  \
# 4820        5161        5181  0.999590
# 4822        4021        4022  0.999557
# 4787        5162        5182  0.999342
# 4681        5271        5274  0.999221
# 4711        5274        5271  0.999142
# 4596        4022        4021  0.999139
# 4634        5182        5162  0.998928
# 4678        4011        4012  0.998864
# 4784        5166        5188  0.998777
# 4734        7483        7485  0.998493
# 3669        2943        2940  0.998049
# 3670        2942        2940  0.998049
# 3671        2941        2940  0.998049
# 4338        5188        5166  0.998039
# 4558        2754        2753  0.997991
# 4653        2822        2622  0.997672
# 4816        2940        2943  0.997610
# 4824        2940        2941  0.997610
# 4818        2940        2942  0.997610
# 4771        1421        1412  0.997574
# 4509        2753        2754  0.997528
# 4586        5523        5522  0.997467
# 3382        9003        9000  0.997352
# 4398        2611        2612  0.997300
# 4755        1421        1411  0.997197
# 4429        7485        7483  0.997180
# 4482        2622        2822  0.996751
# 4235        1543        1589  0.996599
# 4826        9000        9003  0.996481
# 4141        2951        3001  0.996065
# 4313        5522        5523  0.996000
# 4718        3001        5185  0.995967
# 4237        1724        1754  0.995911
# 4685        1754        1724  0.995911
# 4155        1412        1421  0.995903
# 4666        2612        2611  0.995892
# 4657        4012        4011  0.995848
# 4790        1589        1543  0.995657
# 4154        1411        1421  0.995480
# 4803        4100        4200  0.995100
# 2819        4200        4100  0.995063
# 4705        3001        2951  0.994791
# 4775         130         123  0.994406
# 4594        4020        4021  0.994364
# 4406        7250        7210  0.994077
# 4461        2466        2413  0.993814
# 4573        5170        5190  0.993473
# 3559         123         130  0.993380
# 4511        2224        2225  0.993305
#
#                                  SubActivity_StartIndst  \
# 4820                                                NaN
# 4822                                 Manufacture of gas
# 4787                                                NaN
# 4681  Repair of boots, shoes and other articles of l...
# 4711                                      Repair n.e.c.
# 4596  Distribution and trade of gaseous fuels throug...
# 4634  Wholesale of mining, construction and civil en...
# 4678                          Production of electricity
# 4784                                                NaN
# 4734                                                NaN
# 3669          Manufacture of other machine tools n.e.c.
# 3670    Manufacture of other metalworking machine tools
# 3671      Manufacture of portable hand held power tools
# 4338  Wholesale of agricultural machinery and access...
# 4558                Casting of other non-ferrous metals
# 4653  Manufacture of central heating radiators and b...
# 4816                                                NaN
# 4824                                                NaN
# 4818                                                NaN
# 4771                  Operation of gravel and sand pits
# 4509                            Casting of light metals
# 4586  Holiday centres and holiday villages, Other se...
# 3382     Sanitation, remediation and similar activities
# 4398                          Manufacture of flat glass
# 4755                  Operation of gravel and sand pits
# 4429             Secretarial and translation activities
# 4482           Manufacture of ceramic sanitary fixtures
# 4235   Manufacture of margarine and similar edible fats
# 4826                                                NaN
# 4141            Manufacture of machinery for metallurgy
# 4313             Camping sites, including caravan sites
# 4718                    Manufacture of office machinery
# 4237                                  Silk-type weaving
# 4685  Manufacture of narrow fabricsManufacture of ot...
# 4155           Quarrying of limestone, gypsum and chalk
# 4666               Shaping and processing of flat glass
# 4657                        Transmission of electricity
# 4790  Manufacture of soups Manufacture of other food...
# 4154        Quarrying of  ornamental and building stone
# 4803  Collection, purification and distribution of w...
# 2819                                                NaN
# 4705                    Manufacture of office machinery
# 4775                                                NaN
# 4594                                                NaN
# 4406  Maintenance and repair of office, accounting a...
# 4461      Manufacture of other chemical products n.e.c.
# 4573                                                NaN
# 3559                                                NaN
# 4511                               Pre-press activities
#
#                                  SubActivity_FinalIndst  \
# 4820                         Wholesale of machine tools
# 4822  Distribution and trade of gaseous fuels throug...
# 4787  Wholesale of mining, construction and civil en...
# 4681                                      Repair n.e.c.
# 4711  Repair of boots, shoes and other articles of l...
# 4596                                 Manufacture of gas
# 4634                                                NaN
# 4678                        Transmission of electricity
# 4784  Wholesale of agricultural machinery and access...
# 4734             Secretarial and translation activities
# 3669                                                NaN
# 3670                                                NaN
# 3671                                                NaN
# 4338                                                NaN
# 4558                            Casting of light metals
# 4653           Manufacture of ceramic sanitary fixtures
# 4816          Manufacture of other machine tools n.e.c.
# 4824      Manufacture of portable hand held power tools
# 4818    Manufacture of other metalworking machine tools
# 4771           Quarrying of limestone, gypsum and chalk
# 4509                Casting of other non-ferrous metals
# 4586             Camping sites, including caravan sites
# 3382                                                NaN
# 4398               Shaping and processing of flat glass
# 4755        Quarrying of  ornamental and building stone
# 4429                                                NaN
# 4482  Manufacture of central heating radiators and b...
# 4235  Manufacture of soups Manufacture of other food...
# 4826     Sanitation, remediation and similar activities
# 4141                    Manufacture of office machinery
# 4313  Holiday centres and holiday villages, Other se...
# 4718  Wholesale of other office machinery and equipment
# 4237  Manufacture of narrow fabricsManufacture of ot...
# 4685                                  Silk-type weaving
# 4155                  Operation of gravel and sand pits
# 4666                          Manufacture of flat glass
# 4657                          Production of electricity
# 4790   Manufacture of margarine and similar edible fats
# 4154                  Operation of gravel and sand pits
# 4803                                                NaN
# 2819  Collection, purification and distribution of w...
# 4705            Manufacture of machinery for metallurgy
# 4775                                                NaN
# 4594                                 Manufacture of gas
# 4155                     NaN    10.0
# 4666                     NaN    10.0
# 4657                     NaN    10.0
# 4790                     NaN    10.0
# 4154                     NaN    10.0
# 4803                     NaN    10.0
# 2819                     NaN    12.0
# 4705                     NaN    10.0
# 4775                     NaN    19.0
# 4594                     NaN   129.0
# 4406                     NaN   117.0
# 4461                     NaN    34.0
# 4573                     NaN   260.0
# 3559                     NaN    10.0
# 4511                     NaN    13.0

# %%
# links without cuts
print ("Number of links:", reduced_matrix_1997_2008.shape[0])
print ("Number of 4-digit industries observed:")
print (len(np.unique([reduced_matrix_1997_2008['StartIndst'].values,reduced_matrix_1997_2008['FinalIndst'].values])))
# Out:
# Number of links: 4828
# Number of 4-digit industries observed:
# 488

# %%
sub_matrix_1997_2008_flows[['StartIndst','FinalIndst','SubActivity_StartIndst','SubActivity_FinalIndst','Counts','weight']].sort_values(by=['Counts'], ascending=False)[0:10]
# Out:
#       StartIndst  FinalIndst  \
# 5           7511        8010
# 15          8021        8010
# 1725        8511        8514
# 175         8514        8511
# 9           8532        8010
# 1603        5211        7415
# 939         8010        8021
# 2968        7220        7222
# 678         8010        8532
# 156         8531        8511
#
#                                  SubActivity_StartIndst  \
# 5           General (overall) public service activities
# 15                          General secondary education
# 1725  Public sector hospital activities, including N...
# 175                       Other human health activities
# 9     Charitable social work activities without acco...
# 1603  Retail sale by confectioners, tobacconists and...
# 939                                   Primary education
# 2968                                                NaN
# 678                                   Primary education
# 156   Charitable social work activities with accommo...
#
#                                  SubActivity_FinalIndst  Counts    weight
# 5                                     Primary education  3304.0  0.276996
# 15                                    Primary education  2262.0  0.510068
# 1725                      Other human health activities  1893.0  0.687580
# 175   Public sector hospital activities, including N...  1561.0  0.652672
# 9                                     Primary education  1412.0  0.205057
# 1603  Management activities of other non-financial h...  1358.0  0.638713
# 939                         General secondary education  1255.0  0.390316
# 2968              Other software consultancy and supply  1094.0  0.957098
# 678   Charitable social work activities without acco...   951.0  0.078609
# 156   Public sector hospital activities, including N...   891.0  0.229692

# %%
sub_matrix_1997_2008_flows[['StartIndst','FinalIndst','SubActivity_StartIndst','SubActivity_FinalIndst','Counts','weight']].sort_values(by=['weight'], ascending=False)[0:30]
# Out:
#       StartIndst  FinalIndst  \
# 4603        5181        5161
# 4820        5161        5181
# 4822        4021        4022
# 4787        5162        5182
# 4681        5271        5274
# 4711        5274        5271
# 4596        4022        4021
# 4634        5182        5162
# 4678        4011        4012
# 4784        5166        5188
# 4734        7483        7485
# 3669        2943        2940
# 3670        2942        2940
# 3671        2941        2940
# 4338        5188        5166
# 4558        2754        2753
# 4653        2822        2622
# 4818        2940        2942
# 4816        2940        2943
# 4824        2940        2941
# 4771        1421        1412
# 4509        2753        2754
# 4586        5523        5522
# 3382        9003        9000
# 4398        2611        2612
# 4755        1421        1411
# 4429        7485        7483
# 4482        2622        2822
# 4235        1543        1589
# 4826        9000        9003
#
#                                  SubActivity_StartIndst  \
# 4603                         Wholesale of machine tools
# 4820                                                NaN
# 4822                                 Manufacture of gas
# 4787                                                NaN
# 4681  Repair of boots, shoes and other articles of l...
# 4711                                      Repair n.e.c.
# 4596  Distribution and trade of gaseous fuels throug...
# 4634  Wholesale of mining, construction and civil en...
# 4678                          Production of electricity
# 4784                                                NaN
# 4734                                                NaN
# 3669          Manufacture of other machine tools n.e.c.
# 3670    Manufacture of other metalworking machine tools
# 3671      Manufacture of portable hand held power tools
# 4338  Wholesale of agricultural machinery and access...
# 4558                Casting of other non-ferrous metals
# 4653  Manufacture of central heating radiators and b...
# 4818                                                NaN
# 4816                                                NaN
# 4824                                                NaN
# 4771                  Operation of gravel and sand pits
# 4509                            Casting of light metals
# 4586  Holiday centres and holiday villages, Other se...
# 3382     Sanitation, remediation and similar activities
# 4398                          Manufacture of flat glass
# 4755                  Operation of gravel and sand pits
# 4429             Secretarial and translation activities
# 4482           Manufacture of ceramic sanitary fixtures
# 4235   Manufacture of margarine and similar edible fats
# 4826                                                NaN
#
#                                  SubActivity_FinalIndst  Counts    weight
# 4603                                                NaN    10.0  0.999680
# 4820                         Wholesale of machine tools    32.0  0.999590
# 4822  Distribution and trade of gaseous fuels throug...    27.0  0.999557
# 4787  Wholesale of mining, construction and civil en...    42.0  0.999342
# 4681                                      Repair n.e.c.    12.0  0.999221
# 4711  Repair of boots, shoes and other articles of l...    10.0  0.999142
# 4596                                 Manufacture of gas    10.0  0.999139
# 4634                                                NaN    10.0  0.998928
# 4678                        Transmission of electricity    54.0  0.998864
# 4784  Wholesale of agricultural machinery and access...    72.0  0.998777
# 4734             Secretarial and translation activities    49.0  0.998493
# 3669                                                NaN    10.0  0.998049
# 3670                                                NaN    10.0  0.998049
# 3671                                                NaN    10.0  0.998049
# 4338                                                NaN    10.0  0.998039
# 4558                            Casting of light metals    32.0  0.997991
# 4653           Manufacture of ceramic sanitary fixtures    16.0  0.997672
# 4818    Manufacture of other metalworking machine tools    48.0  0.997610
# 4816          Manufacture of other machine tools n.e.c.    55.0  0.997610
# 4824      Manufacture of portable hand held power tools    21.0  0.997610
# 4771           Quarrying of limestone, gypsum and chalk    26.0  0.997574
# 4509                Casting of other non-ferrous metals    22.0  0.997528
# 4586             Camping sites, including caravan sites    57.0  0.997467
# 3382                                                NaN    10.0  0.997352
# 4398               Shaping and processing of flat glass    18.0  0.997300
# 4755        Quarrying of  ornamental and building stone    22.0  0.997197
# 4429                                                NaN    10.0  0.997180
# 4482  Manufacture of central heating radiators and b...    10.0  0.996751
# 4235  Manufacture of soups Manufacture of other food...    15.0  0.996599
# 4826     Sanitation, remediation and similar activities    17.0  0.996481

# %% [markdown]
# ## Connections

# %%
label2 = "Table2_Reduced_matrix_1997_2008_connections"
reduced_matrix_1997_2008_conn = pd.read_csv("../data/"+label2+".csv", index_col=0)

reduced_matrix_1997_2008_conn = reduced_matrix_1997_2008_conn[reduced_matrix_1997_2008_conn['StartIndst']!=0]

sub_matrix_1997_2008_conn_less1 = reduced_matrix_1997_2008_conn[reduced_matrix_1997_2008_conn['weight']<1]
sub_matrix_1997_2008_conn = sub_matrix_1997_2008_conn_less1[sub_matrix_1997_2008_conn_less1['weight']>0]

print ("Number of links:", sub_matrix_1997_2008_conn.shape[0])
print ("Number of 4-digit industries observed:")
print (len(np.unique([sub_matrix_1997_2008_conn['StartIndst'].values,sub_matrix_1997_2008_conn['FinalIndst'].values])))

# 6659                     NaN                     NaN                     NaN
# 6067                     NaN                     NaN                     NaN
# 6914                     NaN                     NaN                     NaN
# 6354                     NaN                     NaN                     NaN
# 6709                     NaN                     NaN                     NaN
# 6904                     NaN                     NaN                     NaN
# 5833                     NaN                     NaN                     NaN
# 6552                     NaN                     NaN                     NaN
# 6490                     NaN                     NaN                     NaN
# 6827                     NaN                     NaN                     NaN
# 6407                     NaN                     NaN                     NaN
# 6944                     NaN                     NaN                     NaN
# 5128                     NaN                     NaN                     NaN
# 6853                     NaN                     NaN                     NaN
# 6594                     NaN                     NaN                     NaN
# 6084                     NaN                     NaN                     NaN
# 6736                     NaN                     NaN                     NaN
# 6697                     NaN                     NaN                     NaN
# 6764                     NaN                     NaN                     NaN
# 6831                     NaN                     NaN                     NaN
# 5894                     NaN                     NaN                     NaN
# 6315                     NaN                     NaN                     NaN
# 6833                     NaN                     NaN                     NaN
# 5126                     NaN                     NaN                     NaN
# 6932                     NaN                     NaN                     NaN
# 6743                     NaN                     NaN                     NaN
# 6090                     NaN                     NaN                     NaN
#
#      MainIndustry_FinalIndst  Counts
# 6813                     NaN    27.0
# 6800                     NaN    25.0
# 6747                     NaN    25.0
# 6937                     NaN    51.0
# 6648                     NaN    51.0
# 6802                     NaN    24.0
# 6722                     NaN    24.0
# 6299                     NaN    23.0
# 6923                     NaN    23.0
# 6849                     NaN    57.0
# 6685                     NaN    57.0
# 6844                     NaN    31.0
# 6745                     NaN    31.0
# 6946                     NaN    37.0
# 6293                     NaN    37.0
# 6559                     NaN    88.0
# 6528                     NaN    88.0
# 6656                     NaN    21.0
# 6677                     NaN    21.0
# 6857                     NaN    89.0
# 6225                     NaN    89.0
# 6514                     NaN    36.0
# 6659                     NaN    36.0
# 6067                     NaN    25.0
# 6914                     NaN    25.0
# 6354                     NaN    34.0
# 6709                     NaN    34.0
# 6904                     NaN    22.0
# 5833                     NaN    22.0
# 6552                     NaN    26.0
# 6490                     NaN    26.0
# 6827                     NaN    68.0
# 6407                     NaN    68.0
# 6944                     NaN    37.0
# 5128                     NaN    37.0
# 6853                     NaN    21.0
# 6594                     NaN    21.0
# 6084                     NaN    26.0
# 6736                     NaN    26.0
# 6697                     NaN    74.0
# 6764                     NaN    74.0
# 6831                     NaN    33.0
# 5894                     NaN    33.0
# 6315                     NaN    25.0
# 6833                     NaN    25.0
# 5126                     NaN    78.0
# 6932                     NaN    78.0
# 6743                     NaN    25.0
# 6090                     NaN    25.0

# %%
# links without cuts
print ("Number of links:", reduced_matrix_1997_2008_conn.shape[0])
print ("Number of 4-digit industries observed:")
print (len(np.unique([reduced_matrix_1997_2008_conn['StartIndst'].values,reduced_matrix_1997_2008_conn['FinalIndst'].values])))
# Out:
# Number of links: 6947
# Number of 4-digit industries observed:
# 497

# %%
sub_matrix_1997_2008_conn[['StartIndst','FinalIndst','SubActivity_StartIndst','SubActivity_FinalIndst','Counts','weight']].sort_values(by=['Counts'], ascending=False)[0:10]
# Out:
#       StartIndst  FinalIndst  \
# 5           7511        8010
# 558         8010        7511
# 15          8021        8010
# 1241        8010        8021
# 214         8514        8511
# 2092        8511        8514
# 877         8010        8532
# 9           8532        8010
# 325         7415        5211
# 2134        5211        7415
#
#                                  SubActivity_StartIndst  \
# 5           General (overall) public service activities
# 558                                   Primary education
# 15                          General secondary education
# 1241                                  Primary education
# 214                       Other human health activities
# 2092  Public sector hospital activities, including N...
# 877                                   Primary education
# 9     Charitable social work activities without acco...
# 325   Management activities of other non-financial h...
# 2134  Retail sale by confectioners, tobacconists and...
#
#                                  SubActivity_FinalIndst  Counts    weight
# 5                                     Primary education  7755.0  0.381917
# 558         General (overall) public service activities  7755.0  0.381917
# 15                                    Primary education  5886.0  0.613482
# 1241                        General secondary education  5886.0  0.613482
# 214   Public sector hospital activities, including N...  5600.0  0.760900
# 2092                      Other human health activities  5600.0  0.760900
# 877   Charitable social work activities without acco...  3838.0  0.324674
# 9                                     Primary education  3838.0  0.324674
# 325   Retail sale by confectioners, tobacconists and...  3056.0  0.660361
# 2134  Management activities of other non-financial h...  3056.0  0.660361

# %%
correlation_industry_pairs(sub_matrix_1997_2008_conn_less1,sub_matrix_1997_2008_less1)


correlation_industry_pairs(sub_matrix_1997_2008_conn_less1,sub_matrix_1997_2008_less1,'counts')
# Out:
# /Users/crangelsmith/PycharmProjects/KnowledgeFlows/python/labour_flows_matrix/src/correlations.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_industry1['id'] = df_industry1.groupby(['StartIndst', 'FinalIndst']).ngroup()
# /anaconda3/envs/kflows/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
# /anaconda3/envs/kflows/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
correlation_industry_pairs(sub_matrix_1997_2008_conn_less1[sub_matrix_1997_2008_conn_less1['Counts']<11],sub_matrix_1997_2008_less1,'weight')


correlation_industry_pairs(sub_matrix_1997_2008_conn_less1[sub_matrix_1997_2008_conn_less1['Counts']>100],sub_matrix_1997_2008_less1,'weight')
# Out:
# /anaconda3/envs/kflows/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
# /anaconda3/envs/kflows/lib/python3.7/site-packages/scipy/stats/stats.py:3033: RuntimeWarning: Mean of empty slice.
#   mx = x.mean()
# /anaconda3/envs/kflows/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /anaconda3/envs/kflows/lib/python3.7/site-packages/scipy/stats/stats.py:3034: RuntimeWarning: Mean of empty slice.
#   my = y.mean()
# /anaconda3/envs/kflows/lib/python3.7/site-packages/scipy/stats/stats.py:3038: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# /anaconda3/envs/kflows/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
Gm_simple_1997_2008_flows = build_network_object(reduced_matrix_1997_2008_flows,'weight')
Gm_simple_1997_2008_conn = build_network_object(reduced_matrix_1997_2008_conn,'weight')

# %%
plt.hist(sub_matrix_1997_2008_less1['Counts'],bins=990)

plt.xlabel('Counts')
plt.ylabel('Frequency')
plt.title('Observed transitions between industries in the period from 2009 to 2018 (flow algorithm)')
plt.xlim(10, 100)
plt.legend()
plt.show()


sub_matrix_1997_2008_less1[sub_matrix_1997_2008_less1['Counts']<35].shape[0]/sub_matrix_1997_2008_less1.shape[0]
# Out:
# No handles with labels found to put in legend.
# 0.813594470046083

# %% [markdown]
# ## Degree comparison:

# %%
print ('NETWORK OF flows')
compare_degrees_strength(Gm_simple_1997_2008_flows)
print()
print()
print ('NETWORK OF connections')
compare_degrees_strength(Gm_simple_1997_2008_conn)
# Out:
# NETWORK OF flows
# mean degree 6.746594005449591
# mean strenght 3.7859163346274283
#
#
# NETWORK OF connections
# mean degree 9.272727272727273
# mean strenght 5.7022668743343

# %%
correlation_network_degree(Gm_simple_1997_2008_conn,Gm_simple_1997_2008_flows,'strength')
correlation_network_degree(Gm_simple_1997_2008_conn,Gm_simple_1997_2008_flows,'degree')
# Out:
# /anaconda3/envs/kflows/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
# /anaconda3/envs/kflows/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ## Adjacency matrix:
# ### Flows:

# %%
draw_adjacency_matrix_nolabel(reduced_matrix_1997_2008_flows[reduced_matrix_1997_2008_flows['weight']>0],['StartIndst','FinalIndst'],'weight')
# Out:
# /anaconda3/envs/kflows/lib/python3.7/site-packages/matplotlib/colorbar.py:600: UserWarning: set_ticks() must have been called.
#   warnings.warn("set_ticks() must have been called.")

# %% [markdown]
# ### Connections:

# %%
draw_adjacency_matrix_nolabel(reduced_matrix_1997_2008_conn[reduced_matrix_1997_2008_conn['weight']>0],['StartIndst','FinalIndst'],'weight')
# Out:
# /anaconda3/envs/kflows/lib/python3.7/site-packages/matplotlib/colorbar.py:600: UserWarning: set_ticks() must have been called.
#   warnings.warn("set_ticks() must have been called.")

# %%
correlation_adjacency_matrix(reduced_matrix_1997_2008_conn,reduced_matrix_1997_2008_flows,'weight')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-b5c2432cee94> in <module>
# ----> 1 correlation_adjacency_matrix(reduced_matrix_1997_2008_conn,reduced_matrix_1997_2008_flows,'weight')
#
# ~/PycharmProjects/KnowledgeFlows/python/labour_flows_matrix/src/correlations.py in correlation_adjacency_matrix(reduced_matrix1, reduced_matrix2, label)
#     117
#     118             name2 = start_df1[start_df1['FinalIndst'] == finalInd]['MainIndustry_StartIndst']
# --> 119             final_df1 = start_df1[start_df1['FinalIndst'] == finalInd]
#     120             final_df2 = start_df2[start_df2['FinalIndst'] == finalInd]
#     121
#
# /anaconda3/envs/kflows/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1772             res_values = com.values_from_object(res)
#    1773             return self._constructor(res_values, index=self.index,
# -> 1774                                      name=res_name, dtype='bool')
#    1775
#    1776     wrapper.__name__ = op_name
#
# /anaconda3/envs/kflows/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     260             else:
#     261                 data = sanitize_array(data, index, dtype, copy,
# --> 262                                       raise_cast_failure=True)
#     263
#     264                 data = SingleBlockManager(data, index, fastpath=True)
#
# /anaconda3/envs/kflows/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     570                         subarr = data.copy()
#     571             else:
# --> 572                 subarr = _try_cast(data, True, dtype, copy, raise_cast_failure)
#     573         elif isinstance(data, Index):
#     574             # don't coerce Index types
#
# /anaconda3/envs/kflows/lib/python3.7/site-packages/pandas/core/internals/construction.py in _try_cast(arr, take_fast_path, dtype, copy, raise_cast_failure)
#     702                                        isinstance(subarr, np.ndarray))):
#     703             subarr = construct_1d_object_array_from_listlike(subarr)
# --> 704         elif not is_extension_type(subarr):
#     705             subarr = construct_1d_ndarray_preserving_na(subarr, dtype,
#     706                                                         copy=copy)
#
# /anaconda3/envs/kflows/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_extension_type(arr)
#    1695     elif is_sparse(arr):
#    1696         return True
# -> 1697     elif is_datetime64tz_dtype(arr):
#    1698         return True
#    1699     return False
#
# /anaconda3/envs/kflows/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_datetime64tz_dtype(arr_or_dtype)
#     465     """
#     466
# --> 467     if arr_or_dtype is None:
#     468         return False
#     469     return DatetimeTZDtype.is_dtype(arr_or_dtype)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Network visualisation: by community
# ## Flows:

# %%
network_components_1997_2008_flows = Gm_simple_1997_2008_flows.components()
network_largest_1997_2008_flows = network_components_1997_2008_flows.subgraphs()[0]

# %%
net_community_1997_2008_flows = network_largest_1997_2008_flows.community_multilevel(weights=network_largest_1997_2008_flows.es['weight'])
print ('Modularity',net_community_1997_2008_flows.modularity)

# %%
list_communities_flows = draw_and_print_communities(network_largest_1997_2008_flows,net_community_1997_2008_flows,'../img/'+label1+'/network_community.png','subactivity')

# %% [markdown]
# ## Connections:

# %%
network_components_1997_2008_conn = Gm_simple_1997_2008_conn.components()
network_largest_1997_2008_conn = network_components_1997_2008_conn.subgraphs()[0]
net_community_1997_2008_conn = network_largest_1997_2008_conn.community_multilevel(weights=network_largest_1997_2008_conn.es['weight'])
print ('Modularity',net_community_1997_2008_conn.modularity)

# %%
list_communities_conn = draw_and_print_communities(network_largest_1997_2008_conn,net_community_1997_2008_conn,'../img/'+label2+'/network_community.png','subactivity')

# %% [markdown]
# ### Flows:

# %% [markdown]
# !['something here'](../img/Table1_Reduced_matrix_1997_2008_flows/network_community.png)

# %% [markdown]
# ### Connections:

# %% [markdown]
# ![title](../img/Table2_Reduced_matrix_1997_2008_connections/network_community.png)

# %%
print (list_communities_conn[1])
print (list_communities_flows[0])

# %%
compare_comunity_intersection(list_communities_conn,list_communities_flows,'Connections','Flows')

# %%
compare_comunity_intersection(list_communities_flows,list_communities_conn,'Flows','Connections')

# %% [markdown]
# # Example of comparison of a network community with itself

# %%
network_components_1997_2008_conn2 = Gm_simple_1997_2008_conn.components()
network_largest_1997_2008_conn2 = network_components_1997_2008_conn2.subgraphs()[0]
net_community_1997_2008_conn2 = network_largest_1997_2008_conn2.community_multilevel(weights=network_largest_1997_2008_conn2.es['weight'])
print ('Modularity',net_community_1997_2008_conn2.modularity)

list_communities_conn2 = draw_and_print_communities(network_largest_1997_2008_conn2,net_community_1997_2008_conn2,'../img/'+label2+'/network_community.png','subactivity')

# %%
compare_comunity_intersection(list_communities_conn,list_communities_conn2,'Connections','Connections2')
